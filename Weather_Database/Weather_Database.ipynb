# %%
# Import the random module.
import random

# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the tuple() function to display the latitude and longitude combinations.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fb468a3f5fa906b026cfdd3bb7524a74

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "portland"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fb468a3f5fa906b026cfdd3bb7524a74&q=portland

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | yar-sale
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | looc
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | pimentel
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | neiafu
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | tual
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | balykshi
# City not found. Skipping...
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | hasaki
# Processing Record 17 of Set 1 | sola
# Processing Record 18 of Set 1 | cherskiy
# Processing Record 19 of Set 1 | fengzhen
# Processing Record 20 of Set 1 | bilma
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | kalianget
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | san cristobal
# Processing Record 25 of Set 1 | puerto escondido
# Processing Record 26 of Set 1 | caravelas
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | thinadhoo
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | dese
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | palmer
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | korla
# Processing Record 35 of Set 1 | tamiahua
# Processing Record 36 of Set 1 | jumla
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 1 | baruun-urt
# Processing Record 40 of Set 1 | port lincoln
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | roebourne
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | vao
# Processing Record 49 of Set 1 | ukiah
# Processing Record 50 of Set 1 | cayenne
# Processing Record 1 of Set 2 | belmonte
# Processing Record 2 of Set 2 | igarka
# Processing Record 3 of Set 2 | vestmannaeyjar
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | kirksville
# Processing Record 6 of Set 2 | hailar
# Processing Record 7 of Set 2 | verkhnevilyuysk
# Processing Record 8 of Set 2 | vostok
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | praia da vitoria
# Processing Record 11 of Set 2 | dudinka
# Processing Record 12 of Set 2 | ulladulla
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | katsuura
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | ust-ordynskiy
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | walvis bay
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | poum
# Processing Record 32 of Set 2 | taby
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | heihe
# Processing Record 36 of Set 2 | dauriya
# Processing Record 37 of Set 2 | vaini
# Processing Record 38 of Set 2 | nikel
# Processing Record 39 of Set 2 | rocha
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | gizo
# Processing Record 42 of Set 2 | puerto ayacucho
# Processing Record 43 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | marrakesh
# Processing Record 46 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 2 | ketchikan
# Processing Record 50 of Set 2 | cam ranh
# Processing Record 1 of Set 3 | floresta
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | ouesso
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | nieuw amsterdam
# Processing Record 6 of Set 3 | tocache
# Processing Record 7 of Set 3 | orange
# Processing Record 8 of Set 3 | rincon
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | maceio
# Processing Record 11 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | surt
# Processing Record 15 of Set 3 | san quintin
# Processing Record 16 of Set 3 | mamakan
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | havelock
# Processing Record 19 of Set 3 | santiago de cao
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | innisfail
# Processing Record 23 of Set 3 | bratsk
# Processing Record 24 of Set 3 | karratha
# Processing Record 25 of Set 3 | san juan
# Processing Record 26 of Set 3 | sitka
# Processing Record 27 of Set 3 | altay
# Processing Record 28 of Set 3 | goderich
# Processing Record 29 of Set 3 | yangambi
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | havre-saint-pierre
# Processing Record 33 of Set 3 | yate
# Processing Record 34 of Set 3 | grand-santi
# Processing Record 35 of Set 3 | kapoeta
# Processing Record 36 of Set 3 | weyburn
# Processing Record 37 of Set 3 | sangar
# Processing Record 38 of Set 3 | maniitsoq
# Processing Record 39 of Set 3 | vila franca do campo
# Processing Record 40 of Set 3 | salalah
# Processing Record 41 of Set 3 | general roca
# Processing Record 42 of Set 3 | ushtobe
# Processing Record 43 of Set 3 | magdagachi
# Processing Record 44 of Set 3 | port hedland
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | salina
# Processing Record 47 of Set 3 | kieta
# Processing Record 48 of Set 3 | bengkulu
# Processing Record 49 of Set 3 | kupang
# Processing Record 50 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | broome
# Processing Record 3 of Set 4 | ostrovnoy
# Processing Record 4 of Set 4 | myskhako
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | mahon
# Processing Record 7 of Set 4 | glinka
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | sokolo
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | kloulklubed
# Processing Record 12 of Set 4 | shingu
# Processing Record 13 of Set 4 | chengdu
# Processing Record 14 of Set 4 | guerrero negro
# Processing Record 15 of Set 4 | riyadh
# Processing Record 16 of Set 4 | shenjiamen
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | sapele
# Processing Record 19 of Set 4 | eydhafushi
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | ambo
# Processing Record 23 of Set 4 | harper
# Processing Record 24 of Set 4 | saint-michel-des-saints
# Processing Record 25 of Set 4 | takoradi
# Processing Record 26 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | portage
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | ulaangom
# Processing Record 31 of Set 4 | indramayu
# Processing Record 32 of Set 4 | carlagan
# Processing Record 33 of Set 4 | sinnamary
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | tansen
# Processing Record 38 of Set 4 | misratah
# Processing Record 39 of Set 4 | youkounkoun
# Processing Record 40 of Set 4 | along
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | buchanan
# Processing Record 45 of Set 4 | margate
# Processing Record 46 of Set 4 | derzhavinsk
# Processing Record 47 of Set 4 | suchitoto
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | aklavik
# Processing Record 50 of Set 4 | lincoln
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | praia
# Processing Record 4 of Set 5 | abu kamal
# Processing Record 5 of Set 5 | lavrentiya
# Processing Record 6 of Set 5 | canandaigua
# Processing Record 7 of Set 5 | chapais
# Processing Record 8 of Set 5 | sao miguel do araguaia
# Processing Record 9 of Set 5 | butaritari
# Processing Record 10 of Set 5 | poltavka
# Processing Record 11 of Set 5 | flinders
# Processing Record 12 of Set 5 | dukat
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | pskov
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | jesup
# Processing Record 17 of Set 5 | berbera
# Processing Record 18 of Set 5 | lethem
# Processing Record 19 of Set 5 | alekseyevsk
# Processing Record 20 of Set 5 | nouadhibou
# Processing Record 21 of Set 5 | lerwick
# Processing Record 22 of Set 5 | kaeo
# Processing Record 23 of Set 5 | mocorito
# Processing Record 24 of Set 5 | oussouye
# Processing Record 25 of Set 5 | luancheng
# Processing Record 26 of Set 5 | chupaca
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | jalu
# Processing Record 29 of Set 5 | itoman
# Processing Record 30 of Set 5 | marawi
# Processing Record 31 of Set 5 | bethel
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | maryville
# Processing Record 34 of Set 5 | hay river
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | anapskaya
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | opunake
# Processing Record 39 of Set 5 | front royal
# Processing Record 40 of Set 5 | olafsvik
# Processing Record 41 of Set 5 | katobu
# Processing Record 42 of Set 5 | labuhan
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | virginia beach
# Processing Record 45 of Set 5 | sabana grande de boya
# Processing Record 46 of Set 5 | ribeira grande
# Processing Record 47 of Set 5 | pacific grove
# Processing Record 48 of Set 5 | kaitangata
# Processing Record 49 of Set 5 | sokoto
# Processing Record 50 of Set 5 | juneau
# Processing Record 1 of Set 6 | bandarbeyla
# Processing Record 2 of Set 6 | kysyl-syr
# Processing Record 3 of Set 6 | gwadar
# Processing Record 4 of Set 6 | namatanai
# Processing Record 5 of Set 6 | kasongo-lunda
# Processing Record 6 of Set 6 | mastic beach
# Processing Record 7 of Set 6 | valparaiso
# Processing Record 8 of Set 6 | atar
# Processing Record 9 of Set 6 | porbandar
# Processing Record 10 of Set 6 | amapa
# Processing Record 11 of Set 6 | aswan
# Processing Record 12 of Set 6 | surab
# Processing Record 13 of Set 6 | lovec
# City not found. Skipping...
# Processing Record 14 of Set 6 | fairbanks
# Processing Record 15 of Set 6 | xining
# Processing Record 16 of Set 6 | quatre cocos
# Processing Record 17 of Set 6 | komsomolskiy
# Processing Record 18 of Set 6 | antalaha
# Processing Record 19 of Set 6 | east london
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | urucara
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | aktash
# Processing Record 24 of Set 6 | itaituba
# Processing Record 25 of Set 6 | rio grande
# Processing Record 26 of Set 6 | outjo
# Processing Record 27 of Set 6 | zyryanka
# Processing Record 28 of Set 6 | itarema
# Processing Record 29 of Set 6 | ballina
# Processing Record 30 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 6 | marion
# Processing Record 32 of Set 6 | makakilo city
# Processing Record 33 of Set 6 | coquimbo
# Processing Record 34 of Set 6 | sampit
# Processing Record 35 of Set 6 | novyy urengoy
# Processing Record 36 of Set 6 | kankan
# Processing Record 37 of Set 6 | morant bay
# Processing Record 38 of Set 6 | susanville
# Processing Record 39 of Set 6 | huoqiu
# Processing Record 40 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 41 of Set 6 | piopio
# Processing Record 42 of Set 6 | powell river
# Processing Record 43 of Set 6 | srednekolymsk
# Processing Record 44 of Set 6 | rockhampton
# Processing Record 45 of Set 6 | cintalapa
# Processing Record 46 of Set 6 | oberwart
# Processing Record 47 of Set 6 | fare
# Processing Record 48 of Set 6 | slave lake
# Processing Record 49 of Set 6 | divnoye
# Processing Record 50 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 1 of Set 7 | deputatskiy
# Processing Record 2 of Set 7 | zhuanghe
# Processing Record 3 of Set 7 | chalons-en-champagne
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | alikovo
# Processing Record 6 of Set 7 | luanda
# Processing Record 7 of Set 7 | eureka
# Processing Record 8 of Set 7 | menongue
# Processing Record 9 of Set 7 | nahrin
# Processing Record 10 of Set 7 | esperance
# Processing Record 11 of Set 7 | vanimo
# Processing Record 12 of Set 7 | port lavaca
# Processing Record 13 of Set 7 | alyangula
# Processing Record 14 of Set 7 | isangel
# Processing Record 15 of Set 7 | cockburn town
# Processing Record 16 of Set 7 | verkhovazhye
# Processing Record 17 of Set 7 | pangnirtung
# Processing Record 18 of Set 7 | danville
# Processing Record 19 of Set 7 | seminole
# Processing Record 20 of Set 7 | moncton
# Processing Record 21 of Set 7 | cabanas
# Processing Record 22 of Set 7 | lensk
# Processing Record 23 of Set 7 | suntar
# Processing Record 24 of Set 7 | saint-louis
# Processing Record 25 of Set 7 | clarence town
# Processing Record 26 of Set 7 | lasa
# Processing Record 27 of Set 7 | ahipara
# Processing Record 28 of Set 7 | ust-nera
# Processing Record 29 of Set 7 | la asuncion
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | lucea
# Processing Record 32 of Set 7 | pangody
# Processing Record 33 of Set 7 | egvekinot
# Processing Record 34 of Set 7 | grindavik
# Processing Record 35 of Set 7 | lata
# Processing Record 36 of Set 7 | saint-augustin
# Processing Record 37 of Set 7 | kavaratti
# Processing Record 38 of Set 7 | strzelce krajenskie
# Processing Record 39 of Set 7 | verkhniy lomov
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | asau
# Processing Record 42 of Set 7 | monthey
# Processing Record 43 of Set 7 | mahebourg
# Processing Record 44 of Set 7 | burriana
# Processing Record 45 of Set 7 | puerto baquerizo moreno
# Processing Record 46 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 7 | ust-maya
# Processing Record 48 of Set 7 | avare
# Processing Record 49 of Set 7 | nara
# Processing Record 50 of Set 7 | polyarnyy
# Processing Record 1 of Set 8 | mende
# Processing Record 2 of Set 8 | westport
# Processing Record 3 of Set 8 | nalut
# Processing Record 4 of Set 8 | gopalganj
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | pasighat
# Processing Record 7 of Set 8 | plettenberg bay
# Processing Record 8 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 8 | san sebastian coatan
# Processing Record 10 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 8 | hamilton
# Processing Record 12 of Set 8 | atambua
# Processing Record 13 of Set 8 | hobyo
# Processing Record 14 of Set 8 | alta floresta
# Processing Record 15 of Set 8 | kapuskasing
# Processing Record 16 of Set 8 | christchurch
# Processing Record 17 of Set 8 | alice springs
# Processing Record 18 of Set 8 | daru
# Processing Record 19 of Set 8 | kosonsoy
# Processing Record 20 of Set 8 | uvarovka
# Processing Record 21 of Set 8 | khani
# Processing Record 22 of Set 8 | san juan de los morros
# Processing Record 23 of Set 8 | malampaka
# Processing Record 24 of Set 8 | severo-yeniseyskiy
# Processing Record 25 of Set 8 | ugoofaaru
# Processing Record 26 of Set 8 | burnie
# Processing Record 27 of Set 8 | kudahuvadhoo
# Processing Record 28 of Set 8 | clyde river
# Processing Record 29 of Set 8 | bima
# Processing Record 30 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 8 | brigantine
# Processing Record 32 of Set 8 | meghri
# Processing Record 33 of Set 8 | jieshi
# Processing Record 34 of Set 8 | ancud
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | mragowo
# Processing Record 37 of Set 8 | aracati
# Processing Record 38 of Set 8 | fenoarivo
# Processing Record 39 of Set 8 | goure
# Processing Record 40 of Set 8 | kingman
# Processing Record 41 of Set 8 | shelburne
# Processing Record 42 of Set 8 | salta
# Processing Record 43 of Set 8 | jimenez
# Processing Record 44 of Set 8 | were ilu
# Processing Record 45 of Set 8 | kuching
# Processing Record 46 of Set 8 | weihe
# Processing Record 47 of Set 8 | rrogozhine
# Processing Record 48 of Set 8 | half moon bay
# Processing Record 49 of Set 8 | vredefort
# Processing Record 50 of Set 8 | muroto
# Processing Record 1 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 9 | pevek
# Processing Record 3 of Set 9 | talavera
# Processing Record 4 of Set 9 | aliquippa
# Processing Record 5 of Set 9 | nenjiang
# Processing Record 6 of Set 9 | opuwo
# Processing Record 7 of Set 9 | imbituba
# Processing Record 8 of Set 9 | gat
# Processing Record 9 of Set 9 | grandola
# Processing Record 10 of Set 9 | beringovskiy
# Processing Record 11 of Set 9 | rawson
# Processing Record 12 of Set 9 | soto la marina
# Processing Record 13 of Set 9 | sambava
# Processing Record 14 of Set 9 | qurayyat
# Processing Record 15 of Set 9 | mehamn
# Processing Record 16 of Set 9 | ashford
# Processing Record 17 of Set 9 | harriston
# Processing Record 18 of Set 9 | sisimiut
# Processing Record 19 of Set 9 | miyako
# Processing Record 20 of Set 9 | nuuk
# Processing Record 21 of Set 9 | nagato
# Processing Record 22 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | kodinsk
# Processing Record 24 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | casper
# Processing Record 26 of Set 9 | suzuka
# Processing Record 27 of Set 9 | ciudad bolivar
# Processing Record 28 of Set 9 | berlevag
# Processing Record 29 of Set 9 | nemuro
# Processing Record 30 of Set 9 | rurrenabaque
# Processing Record 31 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 9 | sakaiminato
# Processing Record 33 of Set 9 | ganzhou
# Processing Record 34 of Set 9 | tura
# Processing Record 35 of Set 9 | chardara
# Processing Record 36 of Set 9 | mae sai
# Processing Record 37 of Set 9 | malaya serdoba
# Processing Record 38 of Set 9 | la gaulette
# City not found. Skipping...
# Processing Record 39 of Set 9 | agirish
# Processing Record 40 of Set 9 | manado
# Processing Record 41 of Set 9 | najran
# Processing Record 42 of Set 9 | rudbar
# Processing Record 43 of Set 9 | great yarmouth
# Processing Record 44 of Set 9 | north bend
# Processing Record 45 of Set 9 | kununurra
# Processing Record 46 of Set 9 | hambantota
# Processing Record 47 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 9 | birao
# Processing Record 49 of Set 9 | paka
# Processing Record 50 of Set 9 | ternate
# Processing Record 1 of Set 10 | fez
# Processing Record 2 of Set 10 | hede
# Processing Record 3 of Set 10 | bom jardim
# Processing Record 4 of Set 10 | bonthe
# Processing Record 5 of Set 10 | vaitape
# Processing Record 6 of Set 10 | darhan
# Processing Record 7 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 8 of Set 10 | haapiti
# Processing Record 9 of Set 10 | samus
# Processing Record 10 of Set 10 | youghal
# Processing Record 11 of Set 10 | dingle
# Processing Record 12 of Set 10 | meulaboh
# Processing Record 13 of Set 10 | abu samrah
# Processing Record 14 of Set 10 | vitim
# Processing Record 15 of Set 10 | kijang
# Processing Record 16 of Set 10 | sabang
# Processing Record 17 of Set 10 | tiarei
# Processing Record 18 of Set 10 | henties bay
# Processing Record 19 of Set 10 | balgazyn
# Processing Record 20 of Set 10 | santa
# Processing Record 21 of Set 10 | nizwa
# Processing Record 22 of Set 10 | majene
# Processing Record 23 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 10 | mareeba
# Processing Record 25 of Set 10 | sug-aksy
# City not found. Skipping...
# Processing Record 26 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 10 | seddon
# Processing Record 29 of Set 10 | tigil
# Processing Record 30 of Set 10 | bandar-e lengeh
# Processing Record 31 of Set 10 | novobirilyussy
# Processing Record 32 of Set 10 | uk
# City not found. Skipping...
# Processing Record 33 of Set 10 | santa margherita ligure
# Processing Record 34 of Set 10 | umm lajj
# Processing Record 35 of Set 10 | safaga
# Processing Record 36 of Set 10 | zhangye
# Processing Record 37 of Set 10 | carballo
# Processing Record 38 of Set 10 | yulara
# Processing Record 39 of Set 10 | vardo
# Processing Record 40 of Set 10 | kruisfontein
# Processing Record 41 of Set 10 | kirakira
# Processing Record 42 of Set 10 | touros
# Processing Record 43 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 44 of Set 10 | ovre ardal
# Processing Record 45 of Set 10 | san policarpo
# Processing Record 46 of Set 10 | labytnangi
# Processing Record 47 of Set 10 | mokhsogollokh
# Processing Record 48 of Set 10 | swan hill
# Processing Record 49 of Set 10 | moose factory
# Processing Record 50 of Set 10 | kuruman
# Processing Record 1 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 11 | chalmette
# Processing Record 3 of Set 11 | houma
# Processing Record 4 of Set 11 | aflao
# Processing Record 5 of Set 11 | aitape
# Processing Record 6 of Set 11 | belaya gora
# Processing Record 7 of Set 11 | belyy yar
# Processing Record 8 of Set 11 | zandvoort
# Processing Record 9 of Set 11 | payson
# Processing Record 10 of Set 11 | heyang
# Processing Record 11 of Set 11 | vagur
# Processing Record 12 of Set 11 | farmington
# Processing Record 13 of Set 11 | klaksvik
# Processing Record 14 of Set 11 | missoula
# Processing Record 15 of Set 11 | neyshabur
# Processing Record 16 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 11 | svetlogorsk
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | tabuk
# Processing Record 20 of Set 11 | gazli
# Processing Record 21 of Set 11 | korhogo
# Processing Record 22 of Set 11 | comodoro rivadavia
# Processing Record 23 of Set 11 | florianopolis
# Processing Record 24 of Set 11 | san jose
# Processing Record 25 of Set 11 | kankakee
# Processing Record 26 of Set 11 | sinjah
# City not found. Skipping...
# Processing Record 27 of Set 11 | nelson bay
# Processing Record 28 of Set 11 | matamoros
# Processing Record 29 of Set 11 | cotonou
# Processing Record 30 of Set 11 | beyneu
# Processing Record 31 of Set 11 | antofagasta
# Processing Record 32 of Set 11 | qaqortoq
# Processing Record 33 of Set 11 | trinidad
# Processing Record 34 of Set 11 | mecca
# Processing Record 35 of Set 11 | ako
# Processing Record 36 of Set 11 | nantucket
# Processing Record 37 of Set 11 | faya
# Processing Record 38 of Set 11 | boa vista
# Processing Record 39 of Set 11 | nyurba
# Processing Record 40 of Set 11 | grants pass
# Processing Record 41 of Set 11 | soyo
# Processing Record 42 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 11 | laguna
# Processing Record 44 of Set 11 | the valley
# Processing Record 45 of Set 11 | orsha
# Processing Record 46 of Set 11 | singkang
# Processing Record 47 of Set 11 | bundaberg
# Processing Record 48 of Set 11 | sawtell
# Processing Record 49 of Set 11 | pacifica
# Processing Record 50 of Set 11 | mercedes
# Processing Record 1 of Set 12 | tomatlan
# Processing Record 2 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 3 of Set 12 | glenluce
# Processing Record 4 of Set 12 | tsiroanomandidy
# Processing Record 5 of Set 12 | rio negro
# Processing Record 6 of Set 12 | susacon
# Processing Record 7 of Set 12 | huanren
# Processing Record 8 of Set 12 | champerico
# Processing Record 9 of Set 12 | porirua
# Processing Record 10 of Set 12 | constitucion
# Processing Record 11 of Set 12 | byron bay
# Processing Record 12 of Set 12 | george
# Processing Record 13 of Set 12 | bambanglipuro
# Processing Record 14 of Set 12 | yeppoon
# Processing Record 15 of Set 12 | torbay
# Processing Record 16 of Set 12 | erzin
# Processing Record 17 of Set 12 | nefteyugansk
# Processing Record 18 of Set 12 | kamenka
# Processing Record 19 of Set 12 | wajir
# Processing Record 20 of Set 12 | batagay
# Processing Record 21 of Set 12 | illapel
# Processing Record 22 of Set 12 | zhigansk
# Processing Record 23 of Set 12 | luau
# Processing Record 24 of Set 12 | mus
# Processing Record 25 of Set 12 | sonqor
# Processing Record 26 of Set 12 | tazovskiy
# Processing Record 27 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 28 of Set 12 | savannah bight
# Processing Record 29 of Set 12 | takhtamygda
# Processing Record 30 of Set 12 | mayo
# Processing Record 31 of Set 12 | awjilah
# Processing Record 32 of Set 12 | victor harbor
# Processing Record 33 of Set 12 | cativa
# Processing Record 34 of Set 12 | assiniboia
# Processing Record 35 of Set 12 | eguia
# Processing Record 36 of Set 12 | avera
# Processing Record 37 of Set 12 | vilhena
# Processing Record 38 of Set 12 | mildura
# Processing Record 39 of Set 12 | bubaque
# Processing Record 40 of Set 12 | dabola
# Processing Record 41 of Set 12 | jeremie
# Processing Record 42 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 12 | placido de castro
# Processing Record 44 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 12 | muzhi
# Processing Record 46 of Set 12 | okahandja
# Processing Record 47 of Set 12 | te anau
# Processing Record 48 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 12 | noumea
# Processing Record 50 of Set 12 | scarborough
# Processing Record 1 of Set 13 | san-pedro
# Processing Record 2 of Set 13 | sechura
# Processing Record 3 of Set 13 | vostochnyy
# Processing Record 4 of Set 13 | ranong
# Processing Record 5 of Set 13 | huancayo
# Processing Record 6 of Set 13 | chumikan
# Processing Record 7 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 13 | pundaguitan
# Processing Record 9 of Set 13 | revda
# Processing Record 10 of Set 13 | nairobi
# Processing Record 11 of Set 13 | pangkalanbuun
# Processing Record 12 of Set 13 | manzhouli
# Processing Record 13 of Set 13 | omachi
# Processing Record 14 of Set 13 | codrington
# Processing Record 15 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 13 | igrim
# Processing Record 17 of Set 13 | leningradskiy
# Processing Record 18 of Set 13 | yima
# Processing Record 19 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 13 | sterling
# Processing Record 21 of Set 13 | valcourt
# Processing Record 22 of Set 13 | hudson bay
# Processing Record 23 of Set 13 | honiara
# Processing Record 24 of Set 13 | koforidua
# Processing Record 25 of Set 13 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 26 of Set 13 | kenora
# Processing Record 27 of Set 13 | mae hong son
# Processing Record 28 of Set 13 | kongolo
# Processing Record 29 of Set 13 | glasgow
# Processing Record 30 of Set 13 | bathsheba
# Processing Record 31 of Set 13 | samarai
# Processing Record 32 of Set 13 | keshan
# City not found. Skipping...
# Processing Record 33 of Set 13 | guane
# Processing Record 34 of Set 13 | hofn
# Processing Record 35 of Set 13 | itapirapua
# Processing Record 36 of Set 13 | lagunas
# Processing Record 37 of Set 13 | saint anthony
# Processing Record 38 of Set 13 | galveston
# Processing Record 39 of Set 13 | camacha
# Processing Record 40 of Set 13 | sucua
# Processing Record 41 of Set 13 | houston
# Processing Record 42 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 13 | paeroa
# Processing Record 44 of Set 13 | brae
# Processing Record 45 of Set 13 | lumby
# Processing Record 46 of Set 13 | vagay
# Processing Record 47 of Set 13 | azare
# Processing Record 48 of Set 13 | baykit
# Processing Record 49 of Set 13 | netolice
# Processing Record 50 of Set 13 | gallup
# Processing Record 1 of Set 14 | preobrazheniye
# Processing Record 2 of Set 14 | pangoa
# Processing Record 3 of Set 14 | celestun
# Processing Record 4 of Set 14 | gawler
# Processing Record 5 of Set 14 | kuminskiy
# Processing Record 6 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 14 | sur
# Processing Record 8 of Set 14 | sao paulo de olivenca
# Processing Record 9 of Set 14 | aloleng
# Processing Record 10 of Set 14 | obo
# Processing Record 11 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 14 | zubova polyana
# Processing Record 13 of Set 14 | quang ngai
# Processing Record 14 of Set 14 | talcahuano
# Processing Record 15 of Set 14 | srandakan
# Processing Record 16 of Set 14 | anzhero-sudzhensk
# Processing Record 17 of Set 14 | ambanja
# Processing Record 18 of Set 14 | davila
# Processing Record 19 of Set 14 | melito di porto salvo
# Processing Record 20 of Set 14 | lake havasu city
# Processing Record 21 of Set 14 | matara
# Processing Record 22 of Set 14 | belgatoy
# Processing Record 23 of Set 14 | puerto colombia
# Processing Record 24 of Set 14 | verkhnetulomskiy
# Processing Record 25 of Set 14 | alofi
# Processing Record 26 of Set 14 | spas-demensk
# Processing Record 27 of Set 14 | staraya mayna
# Processing Record 28 of Set 14 | edd
# Processing Record 29 of Set 14 | fethiye
# Processing Record 30 of Set 14 | batagay-alyta
# Processing Record 31 of Set 14 | el limon
# Processing Record 32 of Set 14 | sioux lookout
# Processing Record 33 of Set 14 | kiama
# Processing Record 34 of Set 14 | hongan
# City not found. Skipping...
# Processing Record 35 of Set 14 | praya
# Processing Record 36 of Set 14 | wenling
# Processing Record 37 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 14 | whitehorse
# Processing Record 39 of Set 14 | magdalena
# Processing Record 40 of Set 14 | standerton
# Processing Record 41 of Set 14 | sakakah
# Processing Record 42 of Set 14 | bahia honda
# Processing Record 43 of Set 14 | talara
# Processing Record 44 of Set 14 | matagami
# Processing Record 45 of Set 14 | rehoboth
# Processing Record 46 of Set 14 | pochutla
# Processing Record 47 of Set 14 | beloha
# Processing Record 48 of Set 14 | remedios
# Processing Record 49 of Set 14 | roma
# Processing Record 50 of Set 14 | emerald
# Processing Record 1 of Set 15 | aleysk
# Processing Record 2 of Set 15 | gorontalo
# Processing Record 3 of Set 15 | yuncheng
# Processing Record 4 of Set 15 | maitum
# Processing Record 5 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 15 | flin flon
# Processing Record 7 of Set 15 | dzhebariki-khaya
# Processing Record 8 of Set 15 | garmsar
# Processing Record 9 of Set 15 | opotiki
# Processing Record 10 of Set 15 | axim
# Processing Record 11 of Set 15 | sarkand
# Processing Record 12 of Set 15 | tarauaca
# Processing Record 13 of Set 15 | malakal
# Processing Record 14 of Set 15 | santa isabel
# Processing Record 15 of Set 15 | batouri
# Processing Record 16 of Set 15 | port blair
# Processing Record 17 of Set 15 | russellville
# Processing Record 18 of Set 15 | buraydah
# Processing Record 19 of Set 15 | buena vista
# Processing Record 20 of Set 15 | stornoway
# Processing Record 21 of Set 15 | padang
# Processing Record 22 of Set 15 | clearwater
# Processing Record 23 of Set 15 | los llanos de aridane
# Processing Record 24 of Set 15 | kahului
# Processing Record 25 of Set 15 | nome
# Processing Record 26 of Set 15 | tolbazy
# Processing Record 27 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 28 of Set 15 | maputo
# Processing Record 29 of Set 15 | maldonado
# Processing Record 30 of Set 15 | cap-aux-meules
# Processing Record 31 of Set 15 | sistranda
# Processing Record 32 of Set 15 | lakatoro
# Processing Record 33 of Set 15 | mizdah
# Processing Record 34 of Set 15 | coxim
# Processing Record 35 of Set 15 | warrington
# Processing Record 36 of Set 15 | aquiraz
# Processing Record 37 of Set 15 | khasan
# Processing Record 38 of Set 15 | puerto morazan
# Processing Record 39 of Set 15 | yumen
# Processing Record 40 of Set 15 | mananjary
# Processing Record 41 of Set 15 | la ronge
# Processing Record 42 of Set 15 | college
# Processing Record 43 of Set 15 | grand gaube
# Processing Record 44 of Set 15 | bintulu
# Processing Record 45 of Set 15 | tevriz
# Processing Record 46 of Set 15 | anuling
# Processing Record 47 of Set 15 | santiago del estero
# Processing Record 48 of Set 15 | tiruvottiyur
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# [{'City': 'Carnarvon', 'Country': 'AU', 'Lat': -24.87, 'Lng': 113.63, 'Max Temp': 62.6, 'Humidity': 77, 'Cloudiness': 0, 'Wind Speed': 14.99, 'Current Description': 'clear sky'}, {'City': 'Yar-Sale', 'Country': 'RU', 'Lat': 66.83, 'Lng': 70.83, 'Max Temp': 50.09, 'Humidity': 93, 'Cloudiness': 26, 'Wind Speed': 12.21, 'Current Description': 'scattered clouds'}, {'City': 'Mataura', 'Country': 'NZ', 'Lat': -46.19, 'Lng': 168.86, 'Max Temp': 44.01, 'Humidity': 94, 'Cloudiness': 12, 'Wind Speed': 1.99, 'Current Description': 'few clouds'}, {'City': 'Looc', 'Country': 'PH', 'Lat': 12.26, 'Lng': 121.99, 'Max Temp': 81.88, 'Humidity': 79, 'Cloudiness': 100, 'Wind Speed': 6.33, 'Current Description': 'overcast clouds'}, {'City': 'Port Elizabeth', 'Country': 'ZA', 'Lat': -33.92, 'Lng': 25.57, 'Max Temp': 60.8, 'Humidity': 77, 'Cloudiness': 97, 'Wind Speed': 5.82, 'Current Description': 'overcast clouds'}, {'City': 'Pimentel', 'Country': 'PE', 'Lat': -6.84, 'Lng': -79.93, 'Max Temp': 65.28, 'Humidity': 72, 'Cloudiness': 0, 'Wind Speed': 14.99, 'Current Description': 'clear sky'}, {'City': 'Cidreira', 'Country': 'BR', 'Lat': -30.18, 'Lng': -50.21, 'Max Temp': 60.44, 'Humidity': 82, 'Cloudiness': 0, 'Wind Speed': 16.37, 'Current Description': 'clear sky'}, {'City': 'Neiafu', 'Country': 'TO', 'Lat': -18.65, 'Lng': -173.98, 'Max Temp': 78.8, 'Humidity': 83, 'Cloudiness': 20, 'Wind Speed': 10.29, 'Current Description': 'few clouds'}, {'City': 'Kapaa', 'Country': 'US', 'Lat': 22.08, 'Lng': -159.32, 'Max Temp': 86, 'Humidity': 70, 'Cloudiness': 40, 'Wind Speed': 10.29, 'Current Description': 'scattered clouds'}, {'City': 'Tual', 'Country': 'ID', 'Lat': -5.67, 'Lng': 132.75, 'Max Temp': 79.03, 'Humidity': 78, 'Cloudiness': 63, 'Wind Speed': 17.31, 'Current Description': 'broken clouds'}, {'City': 'Khatanga', 'Country': 'RU', 'Lat': 71.97, 'Lng': 102.5, 'Max Temp': 54.23, 'Humidity': 69, 'Cloudiness': 96, 'Wind Speed': 9.1, 'Current Description': 'overcast clouds'}, {'City': 'Longyearbyen', 'Country': 'SJ', 'Lat': 78.22, 'Lng': 15.64, 'Max Temp': 40.8, 'Humidity': 69, 'Cloudiness': 3, 'Wind Speed': 6.29, 'Current Description': 'clear sky'}, {'City': 'Hasaki', 'Country': 'JP', 'Lat': 35.73, 'Lng': 140.83, 'Max Temp': 75.2, 'Humidity': 100, 'Cloudiness': 75, 'Wind Speed': 6.93, 'Current Description': 'mist'}, {'City': 'Sola', 'Country': 'VU', 'Lat': -13.88, 'Lng': 167.55, 'Max Temp': 80.98, 'Humidity': 83, 'Cloudiness': 72, 'Wind Speed': 9.95, 'Current Description': 'light rain'}, {'City': 'Cherskiy', 'Country': 'RU', 'Lat': 68.75, 'Lng': 161.3, 'Max Temp': 38.21, 'Humidity': 93, 'Cloudiness': 100, 'Wind Speed': 11.56, 'Current Description': 'light rain'}, {'City': 'Fengzhen', 'Country': 'CN', 'Lat': 40.44, 'Lng': 113.15, 'Max Temp': 54.86, 'Humidity': 86, 'Cloudiness': 31, 'Wind Speed': 5.73, 'Current Description': 'scattered clouds'}, {'City': 'Bilma', 'Country': 'NE', 'Lat': 18.69, 'Lng': 12.92, 'Max Temp': 92.08, 'Humidity': 37, 'Cloudiness': 12, 'Wind Speed': 11.52, 'Current Description': 'moderate rain'}, {'City': 'Bluff', 'Country': 'NZ', 'Lat': -46.6, 'Lng': 168.33, 'Max Temp': 44.01, 'Humidity': 94, 'Cloudiness': 45, 'Wind Speed': 1.99, 'Current Description': 'scattered clouds'}, {'City': 'Kalianget', 'Country': 'ID', 'Lat': -7.05, 'Lng': 113.93, 'Max Temp': 78.49, 'Humidity': 81, 'Cloudiness': 7, 'Wind Speed': 12.8, 'Current Description': 'clear sky'}, {'City': 'San Cristobal', 'Country': 'VE', 'Lat': 7.77, 'Lng': -72.22, 'Max Temp': 87.8, 'Humidity': 45, 'Cloudiness': 40, 'Wind Speed': 19.46, 'Current Description': 'scattered clouds'}, {'City': 'Puerto Escondido', 'Country': 'MX', 'Lat': 15.85, 'Lng': -97.07, 'Max Temp': 80.6, 'Humidity': 74, 'Cloudiness': 90, 'Wind Speed': 5.82, 'Current Description': 'moderate rain'}, {'City': 'Caravelas', 'Country': 'BR', 'Lat': -17.71, 'Lng': -39.25, 'Max Temp': 68.38, 'Humidity': 85, 'Cloudiness': 100, 'Wind Speed': 13.65, 'Current Description': 'light rain'}, {'City': 'Rikitea', 'Country': 'PF', 'L ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Carnarvon      AU -24.87  113.63     62.60        77           0
# 1        Yar-Sale      RU  66.83   70.83     50.09        93          26
# 2         Mataura      NZ -46.19  168.86     44.01        94          12
# 3            Looc      PH  12.26  121.99     81.88        79         100
# 4  Port Elizabeth      ZA -33.92   25.57     60.80        77          97
# 5        Pimentel      PE  -6.84  -79.93     65.28        72           0
# 6        Cidreira      BR -30.18  -50.21     60.44        82           0
# 7          Neiafu      TO -18.65 -173.98     78.80        83          20
# 8           Kapaa      US  22.08 -159.32     86.00        70          40
# 9            Tual      ID  -5.67  132.75     79.03        78          63
#
#    Wind Speed Current Description
# 0       14.99           clear sky
# 1       12.21    scattered clouds
# 2        1.99          few clouds
# 3        6.33     overcast clouds
# 4        5.82     overcast clouds
# 5       14.99           clear sky
# 6       16.37           clear sky
# 7       10.29          few clouds
# 8       10.29    scattered clouds
# 9       17.31       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
